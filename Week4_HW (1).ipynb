# %%
from IPython.display import HTML

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')
# %matplotlib inline

# Increase default figure and font sizes for easier viewing.
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14

# %%
housing_csv = 'data/boston_housing_data.csv'
housing = pd.read_csv(housing_csv)
housing
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %% [markdown]
# 1. Create a line plot of ZN and INDUS in the housing data.
#
# 	a. For ZN, use a solid green line. For INDUS, use a blue dashed line.
#
# 	b. Change the figure size to a width of 12 and height of 8.
#
# 	c. Change the style sheet to something you find https://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html.

# %%
# Plotting Question 1a)
housing.ZN.value_counts().sort_index().plot(color = 'green');
housing.INDUS.value_counts().sort_index().plot(color = 'blue',linestyle='--');

# %%
# Plotting Question 1b)
housing.ZN.value_counts().sort_index().plot(color = 'green',figsize=(12,8));
housing.INDUS.value_counts().sort_index().plot(color = 'blue',linestyle='--',figsize=(12,8));

# %%
#answering question 1c)
UX = housing.ZN.value_counts().sort_index().plot(kind='line', figsize=(10,5));


UX.set_title('BIG PLOT title', fontsize=21,y=1);
# Move the legend to the bottom left corner
UX.legend(loc=3);
plt.style.use('dark_background')
plt.style.use('ggplot')

# %% [markdown]
# 2. Create a bar chart using col1 and col2 of dummy data.
#
# 	a. Give the plot a large title of your choosing.
# 	b. Move the legend to the lower-left corner.
# 	c. Do the same thing but with horizontal bars.
# 	d. Move the legend to the upper-right corner.

# %%
df = pd.DataFrame(np.random.randn(10, 4), 
                  columns=['col1', 'col2', 'col3', 'col4'],
                  index=['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'])

# %%
ax = df.plot(kind='bar', figsize=(15,3));

# Set the title.
ax.set_title('BIG PLOT title', fontsize=35,y=1);

# %%
bx = df.plot(kind='bar', figsize=(15,3));

# Set the title.
bx.set_title('BIG PLOT title', fontsize=21,y=1);
# Move the legend to the bottom left corner
bx.legend(loc=3);

# x-axis labels
bx.set_ylabel('y-axis info', fontsize=16);

# y-axis labels
bx.set_xlabel('x-axis info', fontsize=16);

# %%
#c. and d.
cx = df.plot(kind='barh', figsize=(15,15));

# Set the title.
cx.set_title('BIG PLOT title', fontsize=21,y=1);
# Move the legend to the bottom left corner
cx.legend(loc=1);

# x-axis labels
cx.set_ylabel('y-axis info', fontsize=16);

# y-axis labels
cx.set_xlabel('x-axis info', fontsize=16);

# %% [markdown]
# 3. Create a histogram with pandas for using MEDV in the housing data.
#
# 	a. Set the bins to 20

# %%
housing.MEDV.plot(kind='hist', bins=20);

# %% [markdown]
# 4. Create a scatter plot of two heatmap entries that appear to have a very positive correlation.

# %%
# Generate random heatmap data (positive correlation)
np.random.seed(0)
n = 200
data1 = np.random.rand(n)
data2 = 2 * data1 + np.random.rand(n)  # Positive correlation

# Create a scatter plot
plt.figure(figsize=(10, 8))
plt.scatter(data1, data2, c='cyan', marker='o', label='Data Points')

#plotting the graph
plt.xlabel('Data Point 1')
plt.ylabel('Data Point 2')
plt.title('Scatter Plot QUESTION 4')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 5. Now, create a scatter plot of two heatmap entries that appear to have negative correlation.

# %%
np.random.seed(0)
m = 200
data1 = np.random.rand(m)
data2 = -2 * data1 + np.random.rand(m)  # Negative correlation

# Create a scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(data1, data2, c='red', marker='o', label='Data Points')

# Add labels and a title
plt.xlabel('Data 1')
plt.ylabel('Data 2')
plt.title('Scatter Plot of Two Negatively Correlated Heatmap Entries')

# Show the plot
plt.legend()
plt.grid(True)
plt.show()
